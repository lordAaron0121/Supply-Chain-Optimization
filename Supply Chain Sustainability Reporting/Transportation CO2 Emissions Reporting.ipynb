# %%
import pandas as pd
import warnings
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_columns', None)
pd.options.display.max_seq_items = 2000
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import Shipped Order Lines

# %%
df_lines = pd.read_csv('order_lines.csv', index_col = 0)
print("{:,} order lines to process".format(len(df_lines)))
df_lines.head()
# Out:
# 5,208 order lines to process
#                           Date Month-Year  Warehouse Code Customer Code  \
# 112    2021-01-04 00:00:00.000  1-2021     3403434         5002915-15
# 14485  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 14486  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 14487  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 14488  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
#
#        Order Number  Order Line Number   Item Code  Units   Euros
# 112    20247100      1                  963543-43   2.0    381.47
# 14485  20258239      1                  8902753-53  250.0  187.03
# 14486  20258239      2                  8308591-91  500.0  452.45
# 14487  20258239      3                  8308621-21  500.0  452.45
# 14488  20258239      4                  8022921-21  400.0  567.16

# %% [markdown]
# #### Import Master Data: Unit of Measure Conversions to kg

# %%
df_uom = pd.read_csv('uom_conversions.csv', index_col = 0)
print("{:,} Unit of Measure Conversions".format(len(df_uom)))

# join
df_join = df_lines.copy()
COLS_JOIN = ['Item Code']
df_join = pd.merge(df_join, df_uom, on = COLS_JOIN, how = 'left', suffixes=('', '_y'))
df_join.drop(df_join.filter(regex = '_y$').columns.tolist(), axis = 1, inplace = True)
print("{:,} records".format(len(df_join)))
df_join.head()
# Out:
# 557 Unit of Measure Conversions
# 5,208 records
#                       Date Month-Year  Warehouse Code Customer Code  \
# 0  2021-01-04 00:00:00.000  1-2021     3403434         5002915-15
# 1  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 2  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 3  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 4  2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
#
#    Order Number  Order Line Number   Item Code  Units   Euros  \
# 0  20247100      1                  963543-43   2.0    381.47
# 1  20258239      1                  8902753-53  250.0  187.03
# 2  20258239      2                  8308591-91  500.0  452.45
# 3  20258239      3                  8308621-21  500.0  452.45
# 4  20258239      4                  8022921-21  400.0  567.16
#
#    Conversion Ratio
# 0  56.58400
# 1  0.03200
# 2  0.02219
# 3  0.02219
# 4  0.03200

# %% [markdown]
# #### Import Distances

# %%
df_dist = pd.read_csv('distances.csv', index_col = 0)
df_dist['Location'] = '-'
df_dist['Location'] = df_dist['Customer Country'].astype(str) + ', ' + df_dist['Customer City'].astype(str)
df_dist.head()
# Out:
#       Warehouse Code          Warehouse Name Warehouse Country  \
# 19    3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 610   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 676   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 682   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 1375  3403434         WAREHOUSE PARIS AREA 1  FRANCE
#
#             Warehouse City Customer Code Customer Country    Customer City  \
# 19    CHALONS-EN-CHAMPAGNE  5002915-15    FRANCE           LES ANGLES
# 610   CHALONS-EN-CHAMPAGNE  5397843-43    FRANCE           SUCY EN BRIE
# 676   CHALONS-EN-CHAMPAGNE  5340669-69    GERMANY          PEINE - WOLTORF
# 682   CHALONS-EN-CHAMPAGNE  5340672-72    FRANCE           BELLEVILLE
# 1375  CHALONS-EN-CHAMPAGNE  5029913-13    FRANCE           MOISSY-CRAMAYEL
#
#          Road  Rail  Sea  Air                  Location
# 19    765.728  0.0   0.0  0.0  FRANCE, LES ANGLES
# 610   281.488  0.0   0.0  0.0  FRANCE, SUCY EN BRIE
# 676   856.000  0.0   0.0  0.0  GERMANY, PEINE - WOLTORF
# 682   52.694   0.0   0.0  0.0  FRANCE, BELLEVILLE
# 1375  288.437  0.0   0.0  0.0  FRANCE, MOISSY-CRAMAYEL

# %% [markdown]
# #### Import Cities GPS locations

# %%
df_gps = pd.read_csv('gps_locations.csv', index_col = 0)
print("{:,} Locations".format(len(df_gps)))
df_gps.head()
# Out:
# 19 Locations
#                     Location      GPS 1      GPS 2
# 867   BULGARIA, DOLNI BOGROV  42.701462  23.490811
# 1087  FRANCE, AUBROMETZ       50.303749  2.176058
# 1153  FRANCE, BELLEVILLE      48.871184  2.386682
# 1371  FRANCE, CLICHY CEDEX    48.904099  2.304123
# 1534  FRANCE, GAEL            48.116682 -2.234640

# %% [markdown]
# ### Data Processing

# %% [markdown]
# #### Merge Distance with GPS Location

# %%
df_dist = pd.merge(df_dist, df_gps, on = 'Location', how = 'left', suffixes = ('', '_y'))
df_dist.drop(df_dist.filter(regex = '_y$').columns.tolist(), axis = 1, inplace = True)
df_dist
# Out:
#     Warehouse Code          Warehouse Name Warehouse Country  \
# 0   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 1   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 2   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 3   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 4   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 5   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 6   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 7   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 8   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 9   3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 10  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 11  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 12  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 13  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 14  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 15  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 16  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 17  3403434         WAREHOUSE PARIS AREA 1  FRANCE
# 18  3402002         WAREHOUSE PARIS AREA 2  FRANCE
#
#           Warehouse City Customer Code Customer Country         Customer City  \
# 0   CHALONS-EN-CHAMPAGNE  5002915-15    FRANCE           LES ANGLES
# 1   CHALONS-EN-CHAMPAGNE  5397843-43    FRANCE           SUCY EN BRIE
# 2   CHALONS-EN-CHAMPAGNE  5340669-69    GERMANY          PEINE - WOLTORF
# 3   CHALONS-EN-CHAMPAGNE  5340672-72    FRANCE           BELLEVILLE
# 4   CHALONS-EN-CHAMPAGNE  5029913-13    FRANCE           MOISSY-CRAMAYEL
# 5   CHALONS-EN-CHAMPAGNE  5003451-51    FRANCE           LEVALLOIS PERRET
# 6   CHALONS-EN-CHAMPAGNE  5293132-32    FRANCE           HERLIN LE SEC
# 7   CHALONS-EN-CHAMPAGNE  5003269-69    FRANCE           MACON
# 8   CHALONS-EN-CHAMPAGNE  5003474-74    FRANCE           ORLY
# 9   CHALONS-EN-CHAMPAGNE  5003476-76    FRANCE           VITRY SUR SEINE
# 10  CHALONS-EN-CHAMPAGNE  115-15        FRANCE           CLICHY CEDEX
# 11  CHALONS-EN-CHAMPAGNE  5006517-17    FRANCE           SERRIS
# 12  CHALONS-EN-CHAMPAGNE  5335348-48    UNITED KINGDOM   BRISTOL
# 13  CHALONS-EN-CHAMPAGNE  9001746-46    FRANCE           AUBROMETZ
# 14  CHALONS-EN-CHAMPAGNE  9066250-50    FRANCE           GAEL
# 15  CHALONS-EN-CHAMPAGNE  5334855-55    UNITED KINGDOM   KENT
# 16  CHALONS-EN-CHAMPAGNE  5494889-89    FRANCE           GRETZ ARMAINVILLIERS
# 17  CHALONS-EN-CHAMPAGNE  5262267-67    MAURITANIA       NOUAKCHOTT
# 18  MONTMIRAIL            5486697-97    BULGARIA         DOLNI BOGROV
#
#         Road  Rail     Sea  Air                      Location      GPS 1  \
# 0   765.728   0.0   0.0     0.0  FRANCE, LES ANGLES            42.579678
# 1   281.488   0.0   0.0     0.0  FRANCE, SUCY EN BRIE          48.768810
# 2   856.000   0.0   0.0     0.0  GERMANY, PEINE - WOLTORF      52.304594
# 3   52.694    0.0   0.0     0.0  FRANCE, BELLEVILLE            48.871184
# 4   288.437   0.0   0.0     0.0  FRANCE, MOISSY-CRAMAYEL       48.624666
# 5   295.165   0.0   0.0     0.0  FRANCE, LEVALLOIS PERRET      48.894640
# 6   353.590   0.0   0.0     0.0  FRANCE, HERLIN LE SEC         50.354429
# 7   478.723   0.0   0.0     0.0  FRANCE, MACON                 48.878552
# 8   287.110   0.0   0.0     0.0  FRANCE, ORLY                  48.740227
# 9   284.851   0.0   0.0     0.0  FRANCE, VITRY SUR SEINE       48.789263
# 10  293.858   0.0   0.0     0.0  FRANCE, CLICHY CEDEX          48.904099
# 11  256.250   0.0   0.0     0.0  FRANCE, SERRIS                48.845309
# 12  626.000   0.0   44.0    0.0  UNITED KINGDOM, BRISTOL       51.468489
# 13  357.151   0.0   0.0     0.0  FRANCE, AUBROMETZ             50.303749
# 14  667.613   0.0   0.0     0.0  FRANCE, GAEL                  48.116682
# 15  409.000   0.0   44.0    0.0  UNITED KINGDOM, KENT          51.196396
# 16  268.336   0.0   0.0     0.0  FRANCE, GRETZ ARMAINVILLIERS  48.753586
# 17  300.000   0.0   3739.0  0.0  MAURITANIA, NOUAKCHOTT        18.067171
# 18  2163.000  0.0   0.0     0.0  BULGARIA, DOLNI BOGROV        42.701462
#
#         GPS 2
# 0   2.048950
# 1   2.537369
# 2   10.312521
# 3   2.386682
# 4   2.595756
# 5   2.287419
# 6   2.331766
# 7   2.280117
# 8   2.402965
# 9   2.395103
# 10  2.304123
# 11  2.787302
# 12 -2.590717
# 13  2.176058
# 14 -2.234640
# 15  0.742644
# 16  2.727228
# 17 -15.953561
# 18  23.490811

# %% [markdown]
# #### Final Join to build records

# %%
COLS_JOIN = ['Warehouse Code', 'Customer Code']
df_join = pd.merge(df_join, df_dist, on = COLS_JOIN, how = 'left', suffixes = ('', '_y'))
df_join.drop(df_join.filter(regex='_y$').columns.tolist(), axis = 1, inplace = True)
print("{:,} records".format(len(df_join)))
df_join
# Out:
# 5,208 records
#                          Date Month-Year  Warehouse Code Customer Code  \
# 0     2021-01-04 00:00:00.000  1-2021     3403434         5002915-15
# 1     2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 2     2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 3     2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# 4     2021-01-07 00:00:00.000  1-2021     3403434         5397843-43
# ...                       ...     ...         ...                ...
# 5203  2021-10-28 00:00:00.000  10-2021    3403434         5397843-43
# 5204  2021-10-28 00:00:00.000  10-2021    3403434         5397843-43
# 5205  2021-10-28 00:00:00.000  10-2021    3403434         5397843-43
# 5206  2021-11-01 00:00:00.000  10-2021    3403434         5340669-69
# 5207  2021-11-01 00:00:00.000  10-2021    3403434         5340669-69
#
#       Order Number  Order Line Number   Item Code   Units    Euros  \
# 0     20247100      1                  963543-43   2.0     381.47
# 1     20258239      1                  8902753-53  250.0   187.03
# 2     20258239      2                  8308591-91  500.0   452.45
# 3     20258239      3                  8308621-21  500.0   452.45
# 4     20258239      4                  8022921-21  400.0   567.16
# ...        ...     ..                         ...    ...      ...
# 5203  21089497      84                 802065-65   80.0    72.96
# 5204  21089497      85                 942082-82   200.0   391.88
# 5205  21089497      86                 8022922-22  400.0   581.40
# 5206  21004473      1                  982884-84   2000.0  2980.00
# 5207  21004473      2                  983347-47   2400.0  4848.00
#
#       Conversion Ratio          Warehouse Name Warehouse Country  \
# 0     56.58400          WAREHOUSE PARIS AREA 1  FRANCE
# 1     0.03200           WAREHOUSE PARIS AREA 1  FRANCE
# 2     0.02219           WAREHOUSE PARIS AREA 1  FRANCE
# 3     0.02219           WAREHOUSE PARIS AREA 1  FRANCE
# 4     0.03200           WAREHOUSE PARIS AREA 1  FRANCE
# ...       ...                              ...     ...
# 5203  0.02200           WAREHOUSE PARIS AREA 1  FRANCE
# 5204  0.03200           WAREHOUSE PARIS AREA 1  FRANCE
# 5205  0.03200           WAREHOUSE PARIS AREA 1  FRANCE
# 5206  0.14600           WAREHOUSE PARIS AREA 1  FRANCE
# 5207  0.16950           WAREHOUSE PARIS AREA 1  FRANCE
#
#             Warehouse City Customer Country    Customer City     Road  Rail  \
# 0     CHALONS-EN-CHAMPAGNE  FRANCE           LES ANGLES       765.728  0.0
# 1     CHALONS-EN-CHAMPAGNE  FRANCE           SUCY EN BRIE     281.488  0.0
# 2     CHALONS-EN-CHAMPAGNE  FRANCE           SUCY EN BRIE     281.488  0.0
# 3     CHALONS-EN-CHAMPAGNE  FRANCE           SUCY EN BRIE     281.488  0.0
# 4     CHALONS-EN-CHAMPAGNE  FRANCE           SUCY EN BRIE     281.488  0.0
# ...                    ...     ...                    ...         ...  ...
# 5203  CHALONS-EN-CHAMPAGNE  FRANCE           SUCY EN BRIE     281.488  0.0
# 5204  CHALONS-EN-CHAMPAGNE  FRANCE           SUCY EN BRIE     281.488  0.0
# 5205  CHALONS-EN-CHAMPAGNE  FRANCE           SUCY EN BRIE     281.488  0.0
# 5206  CHALONS-EN-CHAMPAGNE  GERMANY          PEINE - WOLTORF  856.000  0.0
# 5207  CHALONS-EN-CHAMPAGNE  GERMANY          PEINE - WOLTORF  856.000  0.0
#
#       Sea  Air                  Location      GPS 1      GPS 2
# 0     0.0  0.0  FRANCE, LES ANGLES        42.579678  2.048950
# 1     0.0  0.0  FRANCE, SUCY EN BRIE      48.768810  2.537369
# 2     0.0  0.0  FRANCE, SUCY EN BRIE      48.768810  2.537369
# 3     0.0  0.0  FRANCE, SUCY EN BRIE      48.768810  2.537369
# 4     0.0  0.0  FRANCE, SUCY EN BRIE      48.768810  2.537369
# ...   ...  ...                   ...            ...       ...
# 5203  0.0  0.0  FRANCE, SUCY EN BRIE      48.768810  2.537369
# 5204  0.0  0.0  FRANCE, SUCY EN BRIE      48.768810  2.537369
# 5205  0.0  0.0  FRANCE, SUCY EN BRIE      48.768810  2.537369
# 5206  0.0  0.0  GERMANY, PEINE - WOLTORF  52.304594  10.312521
# 5207  0.0  0.0  GERMANY, PEINE - WOLTORF  52.304594  10.312521
#
# [5208 rows x 22 columns]

# %% [markdown]
# #### Calculation at order level

# %%
# Calculate Weight (KG)
df_join['KG'] = df_join['Units'] * df_join['Conversion Ratio']

# Agg by order
GPBY_ORDER = ['Date', 'Month-Year', 
        'Warehouse Code', 'Warehouse Name', 'Warehouse Country', 'Warehouse City',
        'Customer Code', 'Customer Country', 'Customer City','Location', 'GPS 1', 'GPS 2', 
        'Road', 'Rail', 'Sea', 'Air',
        'Order Number', 'Item Code']
df_agg = pd.DataFrame(df_join.groupby(GPBY_ORDER)[['Euros', 'Units', 'KG']].sum())
df_agg.reset_index(inplace = True)
df_agg.head()
# Out:
#                       Date Month-Year  Warehouse Code          Warehouse Name  \
# 0  2021-01-04 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 1  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 2  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 3  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 4  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
#
#   Warehouse Country        Warehouse City Customer Code Customer Country  \
# 0  FRANCE            CHALONS-EN-CHAMPAGNE  5002915-15    FRANCE
# 1  FRANCE            CHALONS-EN-CHAMPAGNE  5340669-69    GERMANY
# 2  FRANCE            CHALONS-EN-CHAMPAGNE  5340672-72    FRANCE
# 3  FRANCE            CHALONS-EN-CHAMPAGNE  5397843-43    FRANCE
# 4  FRANCE            CHALONS-EN-CHAMPAGNE  5397843-43    FRANCE
#
#      Customer City                  Location      GPS 1      GPS 2     Road  \
# 0  LES ANGLES       FRANCE, LES ANGLES        42.579678  2.048950   765.728
# 1  PEINE - WOLTORF  GERMANY, PEINE - WOLTORF  52.304594  10.312521  856.000
# 2  BELLEVILLE       FRANCE, BELLEVILLE        48.871184  2.386682   52.694
# 3  SUCY EN BRIE     FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488
# 4  SUCY EN BRIE     FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488
#
#    Rail  Sea  Air  Order Number   Item Code     Euros  Units          KG
# 0  0.0   0.0  0.0  20247100      963543-43   381.47    2.0    113.16800
# 1  0.0   0.0  0.0  20203388      993081-81   24374.43  153.0  2530.32471
# 2  0.0   0.0  0.0  20203383      993081-81   20391.68  128.0  2116.87296
# 3  0.0   0.0  0.0  20258239      802077-77   408.27    300.0  5.70000
# 4  0.0   0.0  0.0  20258239      8022921-21  567.16    400.0  12.80000

# %% [markdown]
# #### Calculate CO2 = f(KG, Ratios)

# %%
# CO2 Emissions
dict_co2e = dict(zip(['Air' ,'Sea', 'Road', 'Rail'], [2.1, 0.01, 0.096, 0.028]))
MODES = ['Road', 'Rail','Sea', 'Air']
for mode in MODES:
    df_agg['CO2 ' + mode] = df_agg['KG'].astype(float)/1000 * df_agg[mode].astype(float) * dict_co2e[mode]
df_agg['CO2 Total'] = df_agg[['CO2 ' + mode for mode in MODES]].sum(axis = 1)
df_agg.to_csv('detailed_report.csv')
df_agg.head()
# Out:
#                       Date Month-Year  Warehouse Code          Warehouse Name  \
# 0  2021-01-04 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 1  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 2  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 3  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
# 4  2021-01-07 00:00:00.000  1-2021     3403434         WAREHOUSE PARIS AREA 1
#
#   Warehouse Country        Warehouse City Customer Code Customer Country  \
# 0  FRANCE            CHALONS-EN-CHAMPAGNE  5002915-15    FRANCE
# 1  FRANCE            CHALONS-EN-CHAMPAGNE  5340669-69    GERMANY
# 2  FRANCE            CHALONS-EN-CHAMPAGNE  5340672-72    FRANCE
# 3  FRANCE            CHALONS-EN-CHAMPAGNE  5397843-43    FRANCE
# 4  FRANCE            CHALONS-EN-CHAMPAGNE  5397843-43    FRANCE
#
#      Customer City                  Location      GPS 1      GPS 2     Road  \
# 0  LES ANGLES       FRANCE, LES ANGLES        42.579678  2.048950   765.728
# 1  PEINE - WOLTORF  GERMANY, PEINE - WOLTORF  52.304594  10.312521  856.000
# 2  BELLEVILLE       FRANCE, BELLEVILLE        48.871184  2.386682   52.694
# 3  SUCY EN BRIE     FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488
# 4  SUCY EN BRIE     FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488
#
#    Rail  Sea  Air  Order Number   Item Code     Euros  Units          KG  \
# 0  0.0   0.0  0.0  20247100      963543-43   381.47    2.0    113.16800
# 1  0.0   0.0  0.0  20203388      993081-81   24374.43  153.0  2530.32471
# 2  0.0   0.0  0.0  20203383      993081-81   20391.68  128.0  2116.87296
# 3  0.0   0.0  0.0  20258239      802077-77   408.27    300.0  5.70000
# 4  0.0   0.0  0.0  20258239      8022921-21  567.16    400.0  12.80000
#
#      CO2 Road  CO2 Rail  CO2 Sea  CO2 Air   CO2 Total
# 0  8.318967    0.0       0.0      0.0      8.318967
# 1  207.931963  0.0       0.0      0.0      207.931963
# 2  10.708464   0.0       0.0      0.0      10.708464
# 3  0.154030    0.0       0.0      0.0      0.154030
# 4  0.345892    0.0       0.0      0.0      0.345892

# %% [markdown]
# #### Final mapping for visualization

# %%
df_agg['Delivery Mode'] = df_agg[MODES].astype(float).apply(
    lambda t: [mode if t[mode] > 0 else '-' for mode in MODES], axis = 1)
dict_map = dict(zip(df_agg['Delivery Mode'].astype(str).unique(),
                   [i.replace(", '-'",'').replace("'-'",'').replace("'",'') for i in df_agg['Delivery Mode'].astype(str).unique()]))
df_agg['Delivery Mode'] = df_agg['Delivery Mode'].astype(str).map(dict_map)
df_agg
# Out:
#                          Date Month-Year  Warehouse Code  \
# 0     2021-01-04 00:00:00.000  1-2021     3403434
# 1     2021-01-07 00:00:00.000  1-2021     3403434
# 2     2021-01-07 00:00:00.000  1-2021     3403434
# 3     2021-01-07 00:00:00.000  1-2021     3403434
# 4     2021-01-07 00:00:00.000  1-2021     3403434
# ...                       ...     ...         ...
# 5119  2021-10-28 00:00:00.000  10-2021    3403434
# 5120  2021-10-28 00:00:00.000  10-2021    3403434
# 5121  2021-10-28 00:00:00.000  10-2021    3403434
# 5122  2021-11-01 00:00:00.000  10-2021    3403434
# 5123  2021-11-01 00:00:00.000  10-2021    3403434
#
#               Warehouse Name Warehouse Country        Warehouse City  \
# 0     WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 1     WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 2     WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 3     WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 4     WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# ...                      ...     ...                             ...
# 5119  WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 5120  WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 5121  WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 5122  WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
# 5123  WAREHOUSE PARIS AREA 1  FRANCE            CHALONS-EN-CHAMPAGNE
#
#      Customer Code Customer Country    Customer City  \
# 0     5002915-15    FRANCE           LES ANGLES
# 1     5340669-69    GERMANY          PEINE - WOLTORF
# 2     5340672-72    FRANCE           BELLEVILLE
# 3     5397843-43    FRANCE           SUCY EN BRIE
# 4     5397843-43    FRANCE           SUCY EN BRIE
# ...          ...       ...                    ...
# 5119  5397843-43    FRANCE           SUCY EN BRIE
# 5120  5397843-43    FRANCE           SUCY EN BRIE
# 5121  5397843-43    FRANCE           SUCY EN BRIE
# 5122  5340669-69    GERMANY          PEINE - WOLTORF
# 5123  5340669-69    GERMANY          PEINE - WOLTORF
#
#                       Location      GPS 1      GPS 2     Road  Rail  Sea  Air  \
# 0     FRANCE, LES ANGLES        42.579678  2.048950   765.728  0.0   0.0  0.0
# 1     GERMANY, PEINE - WOLTORF  52.304594  10.312521  856.000  0.0   0.0  0.0
# 2     FRANCE, BELLEVILLE        48.871184  2.386682   52.694   0.0   0.0  0.0
# 3     FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488  0.0   0.0  0.0
# 4     FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488  0.0   0.0  0.0
# ...                    ...            ...       ...       ...  ...   ...  ...
# 5119  FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488  0.0   0.0  0.0
# 5120  FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488  0.0   0.0  0.0
# 5121  FRANCE, SUCY EN BRIE      48.768810  2.537369   281.488  0.0   0.0  0.0
# 5122  GERMANY, PEINE - WOLTORF  52.304594  10.312521  856.000  0.0   0.0  0.0
# 5123  GERMANY, PEINE - WOLTORF  52.304594  10.312521  856.000  0.0   0.0  0.0
#
#       Order Number   Item Code     Euros   Units          KG    CO2 Road  \
# 0     20247100      963543-43   381.47    2.0     113.16800   8.318967
# 1     20203388      993081-81   24374.43  153.0   2530.32471  207.931963
# 2     20203383      993081-81   20391.68  128.0   2116.87296  10.708464
# 3     20258239      802077-77   408.27    300.0   5.70000     0.154030
# 4     20258239      8022921-21  567.16    400.0   12.80000    0.345892
# ...        ...             ...     ...      ...        ...         ...
# 5119  21089497      897001-01   233.34    125.0   5.38000     0.145383
# 5120  21089497      919289-89   132.24    80.0    1.36880     0.036989
# 5121  21089497      942082-82   391.88    200.0   6.40000     0.172946
# 5122  21004473      982884-84   2980.00   2000.0  292.00000   23.995392
# 5123  21004473      983347-47   4848.00   2400.0  406.80000   33.429197
#
#       CO2 Rail  CO2 Sea  CO2 Air   CO2 Total Delivery Mode
# 0     0.0       0.0      0.0      8.318967    [Road]
# 1     0.0       0.0      0.0      207.931963  [Road]
# 2     0.0       0.0      0.0      10.708464   [Road]
# 3     0.0       0.0      0.0      0.154030    [Road]
# 4     0.0       0.0      0.0      0.345892    [Road]
# ...   ...       ...      ...           ...       ...
# 5119  0.0       0.0      0.0      0.145383    [Road]
# 5120  0.0       0.0      0.0      0.036989    [Road]
# 5121  0.0       0.0      0.0      0.172946    [Road]
# 5122  0.0       0.0      0.0      23.995392   [Road]
# 5123  0.0       0.0      0.0      33.429197   [Road]
#
# [5124 rows x 27 columns]

# %%
df_agg.to_csv('final_report.csv')
